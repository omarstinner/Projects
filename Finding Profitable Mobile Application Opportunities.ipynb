# %% [markdown]
# # Finding Profitable Mobile Application Opportunities

# %% [markdown]
# ## Introduction
# > The modern world is centered around working with technology, and more specifically with mobile applications. The majority of tasks we complete today are through applications, from browsing social media to checking the balances of our bank accounts. For this reason, mobile applications have become an attractive entity for monetization. Applications that generate large amounts of traffic can be very profitable through selling advertising space on their platforms. The aim of this project is to help recommend profitable mobile app profiles to a mobile app developer client. Our client is interested in strictly making free apps and revenue through such apps are heavily influenced by the number of users that you use the app. That being said, the goal of this project is to figure out which types of apps are likely to attract more users. Throughout this project, we will be extracting our insights from the following two datasets:
#
# > - appstore.csv - A data set containing data about approximately seven thousand iOS apps from the App Store.
# > - playstore.csv - A data set containing data about approximately ten thousand Android apps from Google Play.
#
# > The first part of this notebook will focus on preparing and cleaning the dataset for analysis, while the second part will center on analyzing the cleaned data and synthesizing a recommendation.

# %%
# Importing libaries
import statistics as st
from csv import reader
import pandas as pd
pd.set_option('display.max_rows', None)

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading the datasets
def openfile(filename):
    return list(reader(open(filename)))

appstore_data = openfile("/Users/omarstinner/Data Files/Python Projects/Files/Guided Project - Profitable App Profiles/appstore.csv")
playstore_data = openfile("/Users/omarstinner/Data Files/Python Projects/Files/Guided Project - Profitable App Profiles/playstore.csv")
appstore_header = appstore_data[0]
playstore_header = playstore_data[0]

# %% [markdown]
# ## Part 1: Cleaning The Data

# %%
def faulty_detector(data_set):
    return [data_set.index(row) for row in data_set if len(row) != len(data_set[0])]

faulty_rows_playstore = faulty_detector(playstore_data)
faulty_rows_appstore = faulty_detector(appstore_data)

for index in faulty_rows_playstore:
    playstore_data.pop(index)

# %% [markdown]
# > **Function:** To generate a list of indexes belonging to faulty rows in a dataset
#
# > **What's Happening?** After creating a list of faulty rows for both the Google Playstore and the Apple Appstore, we use the list of faulty rows seperatly to remove the faulty rows in each dataset dataset

# %%
from itertools import groupby 

sorted_playstore = sorted(playstore_data[1:], key=lambda x: (x[0], -int(x[3])))
sorted_appstore = sorted(appstore_data[1:], key=lambda x: (x[1], -int(x[5])))

def remove_duplicates(data_set, column_index):
    return [list(g)[0]for k,g in groupby(data_set, lambda x: x[column_index])]

duplicate_free_playstore = remove_duplicates(sorted_playstore,0)
duplicate_free_appstore = remove_duplicates(sorted_appstore,1)

# %% [markdown]
# > **Function:** To generate a list of a duplicate free dataset
#
# > **What's Happening?** We sort the dataset in descending order based on the "App" column for the Google Playstore and the "track_name" column for the Apple Appstore before feeding it into the function. The function only works when the datasets are sorted. The function then removes the duplicates that succeed the the first instance of an app and we are left with duplicate free datasets

# %%
def non_english_remover(data_set, index):
    return [row for row in data_set if len([i for i in row[index] if ord(i) > 127]) <= 3]

english_playstore = non_english_remover(duplicate_free_playstore, 0)
english_appstore = non_english_remover(duplicate_free_appstore, 1)

# %% [markdown]
# > **Function**: To generate a list of strictly english applications
#
# > **What's Happening?** The function removes applications that have more than 3 characters that have an ASCI value over 127. We are then left with a dataset with only english apps

# %%
def paid_app_remover(data_set, playstore = False):
    if playstore:
        return [row for row in data_set if "$" not in row[7]]
    if playstore == False:
        return [row for row in data_set if float(row[4]) == 0]

ready_playstore = paid_app_remover(english_playstore, True)
ready_appstore = paid_app_remover(english_appstore)
ready_playstore.insert(0, playstore_header)
ready_appstore.insert(0, appstore_header)

# %% [markdown]
# > **Function:** To generate a list of applications that strictly free
#
# > **What's Happening?** For the Apple Appstore, the function removes any row that contains a "$" in the string of the "price" column. For the Google Playstore, the function removes any rows that equal 0 in the "Price" column. We are then left with datasets of only free applications. We then insert the respective headers at the beginning of the each dataset, as they will be needed for when we convert the datasets into a pandas DataFrame.

# %%
pandas_playstore = pd.DataFrame(ready_playstore[1:], columns = ready_playstore[0])
pandas_appstore = pd.DataFrame(ready_appstore[1:], columns = ready_appstore[0])

pandas_playstore["Installs"] = pandas_playstore["Installs"].str.replace("+","")
pandas_playstore["Installs"] = pandas_playstore["Installs"].str.replace(",","")
pandas_playstore["Installs"] = pandas_playstore["Installs"].astype(int)
pandas_appstore["rating_count_tot"] = pandas_appstore["rating_count_tot"].astype(int)

def avg_users_per_genre(data_set, column1, column2):
    return {k : (data_set.loc[data_set[column1] == k, column2].sum())/(data_set[column1] == k).sum() for k in set(data_set[column1].tolist())}

playstore_category_avg_installs = avg_users_per_genre(pandas_playstore, "Category", "Installs")
appstore_primegenre_avg_ratingcounttot = avg_users_per_genre(pandas_appstore, "prime_genre", "rating_count_tot")

playstore_sorted = dict(sorted(playstore_category_avg_installs.items(), key=lambda item: item[1], reverse = True))
appstore_sorted =  dict(sorted(appstore_primegenre_avg_ratingcounttot.items(), key=lambda item: item[1], reverse = True))

for k,v in playstore_sorted.items():
    print(k, ":", v)
    
print("\n")

for k,v in appstore_sorted.items():
    print(k, ":", v)
# Out:
# COMMUNICATION : 38456119.167247385
# VIDEO_PLAYERS : 24727872.452830188
# SOCIAL : 23253652.127118643
# PHOTOGRAPHY : 17840110.40229885
# PRODUCTIVITY : 16787331.344927534
# GAME : 15588015.603248259
# TRAVEL_AND_LOCAL : 13984077.710144928
# ENTERTAINMENT : 11640705.88235294
# TOOLS : 10801391.298666667
# NEWS_AND_MAGAZINES : 9549178.467741935
# BOOKS_AND_REFERENCE : 8767811.894736841
# SHOPPING : 7036877.311557789
# PERSONALIZATION : 5201482.6122448975
# WEATHER : 5074486.197183099
# HEALTH_AND_FITNESS : 4188821.9853479853
# MAPS_AND_NAVIGATION : 4056941.7741935486
# FAMILY : 3695641.8198090694
# SPORTS : 3638640.1428571427
# ART_AND_DESIGN : 1986335.0877192982
# FOOD_AND_DRINK : 1924897.7363636363
# EDUCATION : 1833495.145631068
# BUSINESS : 1712290.1474201474
# LIFESTYLE : 1437816.2687861272
# FINANCE : 1387692.475609756
# HOUSE_AND_HOME : 1331540.5616438356
# DATING : 854028.8303030303
# COMICS : 817657.2727272727
# AUTO_AND_VEHICLES : 647317.8170731707
# LIBRARIES_AND_DEMO : 638503.734939759
# PARENTING : 542603.6206896552
# BEAUTY : 513151.88679245283
# EVENTS : 253542.22222222222
# MEDICAL : 120550.61980830671
#
#
# Navigation : 86090.33333333333
# Reference : 74942.11111111111
# Social Networking : 71548.34905660378
# Music : 57326.530303030304
# Weather : 52279.892857142855
# Book : 39758.5
# Food & Drink : 33333.92307692308
# Finance : 31467.944444444445
# Photo & Video : 28441.54375
# Travel : 28243.8
# Shopping : 26919.690476190477
# Health & Fitness : 23298.015384615384
# Sports : 23008.898550724636
# Games : 22812.92467948718
# News : 21248.023255813954
# Productivity : 21028.410714285714
# Utilities : 18684.456790123455
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Business : 7491.117647058823
# Education : 7003.983050847458
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# > **Function:** To generate a dictionary of average users per genre/category
#
# > **What's Happening?** Before we pass the data set through the function we have to first convert into a Pandas DataFrame and clean it. Converting the dataset into a Pandas DataFrame makes it easier for us to maniplate the data, such as removing parts of a string from a specific column and converting strings to integers as shown above. After the datasets are passed throught the function, we are left with a dictionary of the average amount of users each genre has for the Google Playstore and the Apple Appstore

# %% [markdown]
# ## Part 2: Analyzing The Data

# %% [markdown]
# > To develop a better understanding of which type of app is best to develop, we will further examine the average installs of each genre listed above to recommend a profitable application genre for the Apple App Store and the Google Play Store. The criteria for selecting such a genre will be:
#
# > - A low skewness score in the "Installs" column for the specific genre.
# > - A low count of well-established applications within the genre.
# > - A genre that is popular.

# %%
# Finding the most dominant "Navigation" apps
appstore_navigation = pandas_appstore[pandas_appstore["prime_genre"] == "Navigation"].sort_values("rating_count_tot", ascending = False)
appstore_navigation
# Out:
#              id                                        track_name size_bytes  \
# 2987  323229106   Waze - GPS Navigation, Maps & Real-time Traffic   94139392
# 1141  585027354                Google Maps - Navigation & Transit  120232960
# 1085  329541503                                       Geocaching®  108166144
# 502   504677517       CoPilot GPS – Car Navigation & Offline Maps   82534400
# 1312  344176018  ImmobilienScout24: Real Estate Search in Germany  126867456
# 2150  463431091                              Railway Route Search   46950400
#
#      currency price  rating_count_tot rating_count_ver user_rating  \
# 2987      USD   0.0            345046             3040         4.5
# 1141      USD   0.0            154911             1253         4.5
# 1085      USD   0.0             12811              134         3.5
# 502       USD   0.0              3582               70         4.0
# 1312      USD   0.0               187                0         3.5
# 2150      USD   0.0                 5                0         3.0
#
#      user_rating_ver         ver cont_rating prime_genre sup_devices.num  \
# 2987             4.5        4.24          4+  Navigation              37
# 1141             4.0      4.31.1         12+  Navigation              37
# 1085             1.5         5.3          4+  Navigation              37
# 502              3.5  10.0.0.984          4+  Navigation              38
# 1312             0.0         9.5          4+  Navigation              37
# 2150             0.0      3.17.1          4+  Navigation              37
#
#      ipadSc_urls.num lang.num vpp_lic
# 2987               5       36       1
# 1141               5       34       1
# 1085               0       22       1
# 502                5       25       1
# 1312               5        3       1
# 2150               0        1       1

# %%
# Calculating the Skewness Score for the "rating_count_tot" Column for the "Navigation" column
mean = pandas_appstore[pandas_appstore["prime_genre"] == "Navigation"]["rating_count_tot"].mean()
median = pandas_appstore[pandas_appstore["prime_genre"] == "Navigation"]["rating_count_tot"].median()
std_dev = st.stdev(pandas_appstore[pandas_appstore["prime_genre"] == "Navigation"]["rating_count_tot"])

# Skewness equation
(3*(mean - median)) / std_dev
# Out:
# 1.6627029668430233

# %%
# Calculating the % decrease in total average after removing the well-established applications.
no_big_nav_apps = pandas_appstore[(pandas_appstore["prime_genre"] == "Navigation") & (~pandas_appstore["track_name"].isin(appstore_navigation["track_name"][:2]))]
((86090.33333333333 - (no_big_nav_apps["rating_count_tot"].mean())) / 86090.33333333333) * 100
# Out:
# 95.1838379066949

# %%
# Calculating the count of big players in the genre
pandas_appstore[pandas_appstore["prime_genre"] == "Navigation"]["rating_count_tot"].value_counts().sort_index(ascending = False)
# Out:
# 345046    1
# 154911    1
# 12811     1
# 3582      1
# 187       1
# 5         1
# Name: rating_count_tot, dtype: int64

# %% [markdown]
# > Looking at the table above, we can see that the "Navigation" category is dominated by well-established applications such as "Waze" and "Google Maps". This Category might seem popular, because of its high number of average installs (~86090), however, this is not the case as the category average is highly influenced and skewed by install counts of these applications. This is evident through the skewness score of 1.66 and the percent decrease in average installs of ~ 95% after removing these "big" apps. The category only has 6 applications where most of the installs are coming from two well-established applications, making penetrating this market difficult and not feasible. Let us explore the second most popular genre: "Reference".

# %% [markdown]
# ### Analyzing The "Reference" Genre

# %%
# Finding the most dominant "Reference" apps
appstore_reference = pandas_appstore[pandas_appstore["prime_genre"] == "Reference"].sort_values("rating_count_tot", ascending = False)
appstore_reference
# Out:
#               id                                         track_name  \
# 256    282935706                                              Bible
# 659    308750436              Dictionary.com Dictionary & Thesaurus
# 660    364740856     Dictionary.com Dictionary & Thesaurus for iPad
# 1148   414706506                                   Google Translate
# 1742   388389451  Muslim Pro: Ramadan 2017 Prayer Times, Azan, Q...
# 1830  1130829481  New Furniture Mods - Pocket Wiki & Game Tools ...
# 1651   399452287                         Merriam-Webster Dictionary
# 1840   475772902                                          Night Sky
# 484   1135575003  City Maps for Minecraft PE - The Best Maps for...
# 1478  1132715891  LUCKY BLOCK MOD ™ for Minecraft PC Edition - T...
# 1062  1137683736    GUNS MODS for Minecraft PC Edition - Mods Tools
# 1168  1133678984  Guides for Pokémon GO - Pokemon GO News and Ch...
# 2945   640199958                                               WWDC
# 1264  1133706938  Horror Maps for Minecraft PE - Download The Sc...
# 2872  1003837100                                        VPN Express
# 2160  1156856246    Real Bike Traffic Rider Virtual Reality Glasses
# 1379   671889349  Jishokun-Japanese English Dictionary & Translator
# 3205   980134624                                            教えて!goo
#
#      size_bytes currency price  rating_count_tot rating_count_ver user_rating  \
# 256    92774400      USD   0.0            985920             5320         4.5
# 659   111275008      USD   0.0            200047              177         4.0
# 660   165748736      USD   0.0             54175            10176         4.5
# 1148   65281024      USD   0.0             26786               27         3.5
# 1742  100551680      USD   0.0             18418              706         4.5
# 1830   52959232      USD   0.0             17588            17588         4.5
# 1651  155593728      USD   0.0             16849             1125         4.5
# 1840  596499456      USD   0.0             12122               60         4.5
# 484    90124288      USD   0.0              8535             8535         4.0
# 1478   86874112      USD   0.0              4693             4693         4.0
# 1062   85424128      USD   0.0              1497              245         4.0
# 1168   27029504      USD   0.0               826               58         4.5
# 2945   34959360      USD   0.0               762                7         3.5
# 1264   89927680      USD   0.0               718              718         4.0
# 2872   10645504      USD   0.0                14                1         4.5
# 2160  125990912      USD   0.0                 8                2         3.0
# 1379  225522688      USD   0.0                 0                0         0.0
# 3205   44208128      USD   0.0                 0                0         0.0
#
#      user_rating_ver      ver cont_rating prime_genre sup_devices.num  \
# 256              5.0    7.5.1          4+   Reference              37
# 659              4.0    7.1.3          4+   Reference              37
# 660              4.5      4.0          4+   Reference              24
# 1148             4.5   5.10.0          4+   Reference              37
# 1742             5.0    9.2.1          4+   Reference              37
# 1830             4.5      1.0          4+   Reference              38
# 1651             4.5      4.1          4+   Reference              38
# 1840             4.5    4.4.1          4+   Reference              37
# 484              4.0      1.0          4+   Reference              37
# 1478             4.0      1.0         12+   Reference              37
# 1062             3.0      1.1         12+   Reference              37
# 1168             4.0      1.1         17+   Reference              37
# 2945             4.5    6.0.0          4+   Reference              37
# 1264             4.0      1.0         12+   Reference              37
# 2872             5.0      1.8          4+   Reference              37
# 2160             4.5      8.9         17+   Reference              40
# 1379             0.0  2.10.14         12+   Reference              37
# 3205             0.0    2.2.3         12+   Reference              37
#
#      ipadSc_urls.num lang.num vpp_lic
# 256                5       45       1
# 659                0        1       1
# 660                5        9       1
# 1148               5       59       1
# 1742               5       16       1
# 1830               3        2       1
# 1651               1       12       1
# 1840               5       29       1
# 484                4        1       1
# 1478               4        1       1
# 1062               4        1       1
# 1168               2        1       1
# 2945               5        1       1
# 1264               4        1       1
# 2872               2        2       1
# 2160               5        1       1
# 1379               4        2       1
# 3205               0        1       1

# %%
# Calculating the Skewness Score for the "rating_count_tot" Column for the "Reference" column
mean = pandas_appstore[pandas_appstore["prime_genre"] == "Reference"]["rating_count_tot"].mean()
median = pandas_appstore[pandas_appstore["prime_genre"] == "Reference"]["rating_count_tot"].median()
std_dev = st.stdev(pandas_appstore[pandas_appstore["prime_genre"] == "Reference"]["rating_count_tot"])

# Skewness equation
(3*(mean - median)) / std_dev
# Out:
# 0.8831739195424232

# %%
#Calculating the % decrease in total average after removing the well-established applications.
no_big_ref_apps = pandas_appstore[(pandas_appstore["prime_genre"] == "Reference") & (~pandas_appstore["track_name"].isin(appstore_reference["track_name"][:2]))]
((74942.11111111111 - (no_big_ref_apps["rating_count_tot"].mean())) / 74942.11111111111) * 100
# Out:
# 86.40692482642159

# %%
# Finding the count of big players in the genre
pandas_appstore[pandas_appstore["prime_genre"] == "Reference"]["rating_count_tot"].value_counts().sort_index(ascending = False)
# Out:
# 985920    1
# 200047    1
# 54175     1
# 26786     1
# 18418     1
# 17588     1
# 16849     1
# 12122     1
# 8535      1
# 4693      1
# 1497      1
# 826       1
# 762       1
# 718       1
# 14        1
# 8         1
# 0         2
# Name: rating_count_tot, dtype: int64

# %% [markdown]
# > We see the same pattern in the "Reference" genre as we did in the "Navigation" genre - well-established apps are dominating the category in terms of "Installs" ("Bible", "Dictionary.com"). However, in the "Reference" genre, for the "Installs" column we have a much lower skewness Score of ~0.88. Although this is still a relatively high skewness score, it is much lower than that of the "Navigation" genre and indicates that its "Installs" count is influenced by more than just a couple of applications. Also, the average percent decrease in the number of installs has improved relative to the "Navigation" genre (95% vs 86%) making developing a "Reference" application a viable option. The category has many more applications than that of the "Navigation" category further indicating greater potential in this genre. Coupled with the fact that the genre in itself is popular, the "Reference" genre seems to be a feasible and practical option for new mobile development.

# %% [markdown]
# ### Google Playstore

# %%
# Finding the most dominant "COMMUNICATION" apps
playstore_communication = pandas_playstore[(pandas_playstore["Category"] == "COMMUNICATION") & ((pandas_playstore["Installs"] == 500000000) | (pandas_playstore["Installs"] == 100000000) | (pandas_playstore["Installs"] == 1000000000))]
playstore_communication
# Out:
#                                                     App       Category Rating  \
# 641                                    Android Messages  COMMUNICATION    4.2
# 872                         BBM - Free Calls & Messages  COMMUNICATION    4.3
# 4127                     Firefox Browser fast & private  COMMUNICATION    4.4
# 4399         GO SMS Pro - Messenger, Free Themes, Emoji  COMMUNICATION    4.4
# 4502                                              Gmail  COMMUNICATION    4.3
# 4552                       Google Chrome: Fast & Secure  COMMUNICATION    4.3
# 4556              Google Duo - High Quality Video Calls  COMMUNICATION    4.6
# 4737                                           Hangouts  COMMUNICATION    4.0
# 5120                       KakaoTalk: Free Calls & Text  COMMUNICATION    4.3
# 5166                                                Kik  COMMUNICATION    4.3
# 5236                        LINE: Free Calls & Messages  COMMUNICATION    4.2
# 5689              Messenger Lite: Free Calls & Messages  COMMUNICATION    4.4
# 5693           Messenger – Text and Video Chat for Free  COMMUNICATION    4.0
# 6239                     Opera Browser: Fast and Secure  COMMUNICATION    4.4
# 6240                      Opera Mini - fast web browser  COMMUNICATION    4.5
# 7221                      Skype - free IM & video calls  COMMUNICATION    4.1
# 7644                                           Telegram  COMMUNICATION    4.4
# 7928  Truecaller: Caller ID, SMS spam blocking & Dialer  COMMUNICATION    4.5
# 7982        UC Browser - Fast Download Private & Secure  COMMUNICATION    4.5
# 7983        UC Browser Mini -Tiny Fast Private & Secure  COMMUNICATION    4.4
# 8116                                    Viber Messenger  COMMUNICATION    4.3
# 8272                                             WeChat  COMMUNICATION    4.2
# 8325                                 WhatsApp Messenger  COMMUNICATION    4.4
# 8345                                                Who  COMMUNICATION    4.3
# 8454                        Yahoo Mail – Stay Organized  COMMUNICATION    4.3
# 8740                       imo beta free calls and text  COMMUNICATION    4.3
# 8741                      imo free video calls and chat  COMMUNICATION    4.3
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# 641     781810  Varies with device   100000000  Free     0       Everyone
# 872   12843436  Varies with device   100000000  Free     0       Everyone
# 4127   3075118  Varies with device   100000000  Free     0       Everyone
# 4399   2876500                 24M   100000000  Free     0       Everyone
# 4502   4604483  Varies with device  1000000000  Free     0       Everyone
# 4552   9643041  Varies with device  1000000000  Free     0       Everyone
# 4556   2083237  Varies with device   500000000  Free     0       Everyone
# 4737   3419513  Varies with device  1000000000  Free     0       Everyone
# 5120   2546549  Varies with device   100000000  Free     0       Everyone
# 5166   2451136  Varies with device   100000000  Free     0           Teen
# 5236  10790289  Varies with device   500000000  Free     0       Everyone
# 5689   1429038  Varies with device   100000000  Free     0       Everyone
# 5693  56646578  Varies with device  1000000000  Free     0       Everyone
# 6239   2473795  Varies with device   100000000  Free     0       Everyone
# 6240   5150801  Varies with device   100000000  Free     0       Everyone
# 7221  10484169  Varies with device  1000000000  Free     0       Everyone
# 7644   3128611  Varies with device   100000000  Free     0     Mature 17+
# 7928   7820775  Varies with device   100000000  Free     0       Everyone
# 7982  17714850                 40M   500000000  Free     0           Teen
# 7983   3648765                3.3M   100000000  Free     0           Teen
# 8116  11335481  Varies with device   500000000  Free     0       Everyone
# 8272   5387631  Varies with device   100000000  Free     0       Everyone
# 8325  69119316  Varies with device  1000000000  Free     0       Everyone
# 8345   2451093  Varies with device   100000000  Free     0           Teen
# 8454   4188345                 16M   100000000  Free     0       Everyone
# 8740    659395                 11M   100000000  Free     0       Everyone
# 8741   4785988                 11M   500000000  Free     0       Everyone
#
#              Genres    Last Updated               Current Ver  \
# 641   Communication  August 1, 2018        Varies with device
# 872   Communication  August 2, 2018        Varies with device
# 4127  Communication   July 10, 2018        Varies with device
# 4399  Communication  August 1, 2018                      7.73
# 4502  Communication  August 2, 2018        Varies with device
# 4552  Communication  August 1, 2018        Varies with device
# 4556  Communication   July 31, 2018  37.1.206017801.DR37_RC14
# 4737  Communication   July 21, 2018        Varies with device
# 5120  Communication  August 3, 2018        Varies with device
# 5166  Communication  August 3, 2018        Varies with device
# 5236  Communication   July 26, 2018        Varies with device
# 5689  Communication   July 25, 2018              37.0.0.7.163
# 5693  Communication  August 1, 2018        Varies with device
# 6239  Communication   July 31, 2018          47.1.2249.129326
# 6240  Communication   July 19, 2018        Varies with device
# 7221  Communication  August 3, 2018        Varies with device
# 7644  Communication   July 27, 2018        Varies with device
# 7928  Communication  August 1, 2018        Varies with device
# 7982  Communication  August 2, 2018               12.8.5.1121
# 7983  Communication   July 18, 2018                    11.4.0
# 8116  Communication   July 18, 2018        Varies with device
# 8272  Communication   July 31, 2018        Varies with device
# 8325  Communication  August 3, 2018        Varies with device
# 8345  Communication  August 3, 2018        Varies with device
# 8454  Communication   July 18, 2018                    5.29.3
# 8740  Communication    June 7, 2018          9.8.000000010492
# 8741  Communication    June 8, 2018          9.8.000000010501
#
#              Android Ver
# 641   Varies with device
# 872         4.0.3 and up
# 4127  Varies with device
# 4399          4.0 and up
# 4502  Varies with device
# 4552  Varies with device
# 4556          4.4 and up
# 4737  Varies with device
# 5120  Varies with device
# 5166  Varies with device
# 5236  Varies with device
# 5689          2.3 and up
# 5693  Varies with device
# 6239  Varies with device
# 6240  Varies with device
# 7221  Varies with device
# 7644  Varies with device
# 7928  Varies with device
# 7982          4.0 and up
# 7983          4.0 and up
# 8116  Varies with device
# 8272  Varies with device
# 8325  Varies with device
# 8345  Varies with device
# 8454          4.4 and up
# 8740          4.0 and up
# 8741          4.0 and up

# %%
# Calculating the Skewness Score for the "Installs" Column for the "COMMUNIATION" column
mean = pandas_playstore[pandas_playstore["Category"] == "COMMUNICATION"]["Installs"].mean()
median = pandas_playstore[pandas_playstore["Category"] == "COMMUNICATION"]["Installs"].median()
std_dev = st.stdev(pandas_playstore[pandas_playstore["Category"] == "COMMUNICATION"]["Installs"])

(3*(mean - median)) / std_dev
# Out:
# 0.7274286367664985

# %%
# Calculating the percentage decrese in the average installs when the "big" COMMNICATION apps are removed
no_big_comm_apps = pandas_playstore[(pandas_playstore["Category"] == "COMMUNICATION") & (~pandas_playstore["App"].isin(playstore_communication["App"]))]
((38456119.167247385 - (no_big_comm_apps["Installs"].mean())) / 38456119.167247385) * 100
90.62961768765638
# Out:
# 90.62961768765638

# %%
# Finding the count of big players in the genre
pandas_playstore[pandas_playstore["Category"] == "COMMUNICATION"]["Installs"].value_counts().sort_index(ascending = False)
# Out:
# 1000000000     6
# 500000000      5
# 100000000     16
# 50000000       7
# 10000000      43
# 5000000       22
# 1000000       40
# 500000         9
# 100000        16
# 50000         10
# 10000         20
# 5000          16
# 1000          19
# 500            8
# 100           28
# 50             5
# 10            14
# 5              2
# 1              1
# Name: Installs, dtype: int64

# %% [markdown]
# > The most popular category in the app store is "COMMUNICATION". However, after further inspection, we see that the mobile applications we would be competing with are: "Gmail", "Google Chrome", "Hangouts", "Messenger", "Skype", and "WhatsApp" etc. As we can see we have 27 apps skewing the average for all 287 applications in this Category. This shows us that these applications hold the biggest market share in the "COMMUNICATION" mobile app industry and it wouldn't make sense to try and penetrate such a market with already established players. After removing them we can see that the average installs for the "COMMUNICATION" category fell 90%. This indicates that the majority of the "Install" averages were made up of the above-listed applications. Also, the skewness Score of ~0.72 makes the "COMMUNICATION" category not a feasible option for profitable mobile development. Let us explore the second most popular category: "VIDEO_PLAYERS".

# %% [markdown]
# ### Analyzing The "VIDEO_PLAYERS" Category

# %%
# Finding the most dominant "VIDEO_PLAYER" apps
playstore_video_players = pandas_playstore[(pandas_playstore["Category"] == "VIDEO_PLAYERS") & ((pandas_playstore["Installs"] == 500000000) | (pandas_playstore["Installs"] == 100000000) | (pandas_playstore["Installs"] == 1000000000))]
playstore_video_players
# Out:
#                                                     App       Category Rating  \
# 3220                                           Dubsmash  VIDEO_PLAYERS    4.2
# 4571                            Google Play Movies & TV  VIDEO_PLAYERS    3.7
# 5518                                          MX Player  VIDEO_PLAYERS    4.5
# 5848                                  Motorola FM Radio  VIDEO_PLAYERS    3.9
# 5849                                   Motorola Gallery  VIDEO_PLAYERS    3.9
# 8084                                    VLC for Android  VIDEO_PLAYERS    4.4
# 8140  VideoShow-Video Editor, Video Maker, Beauty Ca...  VIDEO_PLAYERS    4.6
# 8177             VivaVideo - Video Editor & Photo Movie  VIDEO_PLAYERS    4.6
# 8485                                            YouTube  VIDEO_PLAYERS    4.3
#
#        Reviews                Size    Installs  Type Price Content Rating  \
# 3220   1971777                 29M   100000000  Free     0           Teen
# 4571    906384  Varies with device  1000000000  Free     0           Teen
# 5518   6474672  Varies with device   500000000  Free     0       Everyone
# 5848     54815  Varies with device   100000000  Free     0       Everyone
# 5849    121916                 23M   100000000  Free     0       Everyone
# 8084   1032076  Varies with device   100000000  Free     0       Everyone
# 8140   4016834  Varies with device   100000000  Free     0       Everyone
# 8177   9879473                 40M   100000000  Free     0           Teen
# 8485  25655305  Varies with device  1000000000  Free     0           Teen
#
#                        Genres      Last Updated         Current Ver  \
# 3220  Video Players & Editors      May 11, 2018              2.35.8
# 4571  Video Players & Editors    August 6, 2018  Varies with device
# 5518  Video Players & Editors    August 6, 2018  Varies with device
# 5848  Video Players & Editors       May 2, 2018  Varies with device
# 5849  Video Players & Editors  January 25, 2016  Varies with device
# 8084  Video Players & Editors     July 30, 2018  Varies with device
# 8140  Video Players & Editors     July 23, 2018  Varies with device
# 8177  Video Players & Editors    August 4, 2018               7.2.1
# 8485  Video Players & Editors    August 2, 2018  Varies with device
#
#              Android Ver
# 3220          4.1 and up
# 4571  Varies with device
# 5518  Varies with device
# 5848  Varies with device
# 5849  Varies with device
# 8084          2.3 and up
# 8140  Varies with device
# 8177          4.1 and up
# 8485  Varies with device

# %%
# Calculating the Skewness Score for the "Installs" Column for the "VIDEO_PLAYERS" column
mean = pandas_playstore[pandas_playstore["Category"] == "VIDEO_PLAYERS"]["Installs"].mean()
median = pandas_playstore[pandas_playstore["Category"] == "VIDEO_PLAYERS"]["Installs"].median()
std_dev = st.stdev(pandas_playstore[pandas_playstore["Category"] == "VIDEO_PLAYERS"]["Installs"])

(3*(mean - median)) / std_dev
# Out:
# 0.5977613211001883

# %%
# Calculating the percentage decrese in the average installs when the "big" "VIDEO_PLAYER" apps ar removed
no_big_video_players_apps = pandas_playstore[(pandas_playstore["Category"] == "VIDEO_PLAYERS") & (~pandas_playstore["App"].isin(playstore_video_players["App"]))]
((24727872.452830188 - (no_big_video_players_apps["Installs"].mean())) / 24727872.452830188) * 100
# Out:
# 77.57640434327497

# %%
# Finding the count of big players in the genre
pandas_playstore[pandas_playstore["Category"] == "VIDEO_PLAYERS"]["Installs"].value_counts().sort_index(ascending = False)
# Out:
# 1000000000     2
# 500000000      1
# 100000000      6
# 50000000      10
# 10000000      26
# 5000000        7
# 1000000       33
# 500000         4
# 100000        12
# 50000          6
# 10000         15
# 5000          14
# 1000           8
# 500            6
# 100            7
# 10             2
# Name: Installs, dtype: int64

# %% [markdown]
# > We see a similar pattern in the "VIDEO_PLAYER" category as we did in the "COMMUNICATION" category, where 9 apps are skewing the average installs for all 159 applications. After removing such "big" applications and recalculating the average for the "VIDEO_PLAYER" category, the average fell by 77%, indicating how strong of a position "Dubsmash" and "Google Play Movies" have in the "VIDEO_PLAYER" mobile app market. However, we see an improvement in skewness score of ~0.59, indicating that there are more applications that are influencing the "Installs" average relative to the "COMMUNICATION" category. Although we see an improvement, we also need to pick a genre that is mutually available in the Apple App Store. For that reason coupled with the fact that there are still a small number of apps controlling the average "Install" count, we will have to pick another category. Since the "Reference" genre in the Apple App Store was a viable option, let us explore a similar category in the Google Play Store, the "BOOK_AND_REFERENCES" category.

# %% [markdown]
# ### Analyzing The "BOOKS_AND_REFERENCE" Category

# %%
# Finding the most dominant "BOOKS_AND_REFERENCE" apps
playstore_books_and_references = pandas_playstore[(pandas_playstore["Category"] == "BOOKS_AND_REFERENCE") & ((pandas_playstore["Installs"] == 500000000) | (pandas_playstore["Installs"] == 100000000) | (pandas_playstore["Installs"] == 1000000000))]
playstore_books_and_references
# Out:
#                           App             Category Rating  Reviews  \
# 615             Amazon Kindle  BOOKS_AND_REFERENCE    4.2   814151
# 770   Audiobooks from Audible  BOOKS_AND_REFERENCE    4.5   568922
# 1446                    Bible  BOOKS_AND_REFERENCE    4.7  2440695
# 4569        Google Play Books  BOOKS_AND_REFERENCE    3.9  1433233
# 8264     Wattpad 📖 Free Books  BOOKS_AND_REFERENCE    4.6  2915189
#
#                     Size    Installs  Type Price Content Rating  \
# 615   Varies with device   100000000  Free     0           Teen
# 770   Varies with device   100000000  Free     0           Teen
# 1446  Varies with device   100000000  Free     0           Teen
# 4569  Varies with device  1000000000  Free     0           Teen
# 8264  Varies with device   100000000  Free     0           Teen
#
#                  Genres    Last Updated         Current Ver  \
# 615   Books & Reference   July 27, 2018  Varies with device
# 770   Books & Reference  August 1, 2018  Varies with device
# 1446  Books & Reference  August 2, 2018  Varies with device
# 4569  Books & Reference  August 3, 2018  Varies with device
# 8264  Books & Reference  August 1, 2018  Varies with device
#
#              Android Ver
# 615   Varies with device
# 770   Varies with device
# 1446  Varies with device
# 4569  Varies with device
# 8264  Varies with device

# %%
# Calculating the Skewness Score for the "Installs" Column for the "BOOKS_AND_REFERENCES" column
mean = pandas_playstore[pandas_playstore["Category"] == "BOOKS_AND_REFERENCE"]["Installs"].mean()
median = pandas_playstore[pandas_playstore["Category"] == "BOOKS_AND_REFERENCE"]["Installs"].median()
std_dev = st.stdev(pandas_playstore[pandas_playstore["Category"] == "BOOKS_AND_REFERENCE"]["Installs"])

(3*(mean - median)) / std_dev
# Out:
# 0.35469872992266904

# %%
# Calculating the percentage decrese in the average installs when the "big" "BOOKS_AND_REFERENCES" apps ar removed
no_big_books_and_references_apps = pandas_playstore[(pandas_playstore["Category"] == "BOOKS_AND_REFERENCE") & (~pandas_playstore["App"].isin(playstore_books_and_references["App"]))]
((8767811.894736841 - (no_big_books_and_references_apps["Installs"].mean())) / 8767811.894736841) * 100
# Out:
# 83.60808564929468

# %%
# Finding the count of big players in the genre
pandas_playstore[pandas_playstore["Category"] == "BOOKS_AND_REFERENCE"]["Installs"].value_counts().sort_index(ascending = False)
# Out:
# 1000000000     1
# 100000000      4
# 10000000      19
# 5000000        9
# 1000000       20
# 500000        16
# 100000        20
# 50000         11
# 10000         23
# 5000          14
# 1000          30
# 500            7
# 100            6
# 50             2
# 10             4
# 5              4
# Name: Installs, dtype: int64

# %% [markdown]
# > We still see the same trend of a couple of applications influencing the average installs. This is evident when we calculate the percent decrease in average installs (-83%) after removing the above "BOOKS_AND_REFERENCES" applications. However, the "REFERENCE_AND_BOOKS" category does have a significantly lower skewness score of ~0.35, making it a more attractive genre to develop a profitable mobile application. The genre only has one application ("Google Play Books") that has 1,000,000,000 installs (unlike the "COMMUNICATION" and "VIDEO_PLAYER" categories), This shows that there is only a handful of very popular applications in this category, leaving us with an opportunity to create an app. Developing a profitable app in this genre is a feasible option as there are opportunities in both stores, the Apple App Store and the Google Play Store. Now that we have settled on a genre, let’s specifically pick a type of application to develop. Let us take look at the apps in these categories in both the Apple App Store and the Google Play Store.

# %%
pandas_playstore[pandas_playstore["Category"] == "BOOKS_AND_REFERENCE"][:100].sort_values("Installs", ascending = False)
# Out:
#                                                     App             Category  \
# 615                                       Amazon Kindle  BOOKS_AND_REFERENCE
# 1446                                              Bible  BOOKS_AND_REFERENCE
# 770                             Audiobooks from Audible  BOOKS_AND_REFERENCE
# 2480                                        Cool Reader  BOOKS_AND_REFERENCE
# 3678                           English Hindi Dictionary  BOOKS_AND_REFERENCE
# 3675                       English Dictionary - Offline  BOOKS_AND_REFERENCE
# 546                           Al'Quran Bahasa Indonesia  BOOKS_AND_REFERENCE
# 3015  Dictionary.com: Find Definitions for English W...  BOOKS_AND_REFERENCE
# 543                                  Al Quran Indonesia  BOOKS_AND_REFERENCE
# 3013                       Dictionary - Merriam-Webster  BOOKS_AND_REFERENCE
# 3012                                         Dictionary  BOOKS_AND_REFERENCE
# 549                                     Al-Quran (Free)  BOOKS_AND_REFERENCE
# 566                                  Aldiko Book Reader  BOOKS_AND_REFERENCE
# 81                  50000 Free eBooks & Free AudioBooks  BOOKS_AND_REFERENCE
# 637                                            Ancestry  BOOKS_AND_REFERENCE
# 1447                                          Bible KJV  BOOKS_AND_REFERENCE
# 3014                               Dictionary - WordWeb  BOOKS_AND_REFERENCE
# 3586                                       Ebook Reader  BOOKS_AND_REFERENCE
# 553                      AlReader -any text book reader  BOOKS_AND_REFERENCE
# 3685                        English to Hindi Dictionary  BOOKS_AND_REFERENCE
# 540       Al Quran : EAlim - Translations & MP3 Offline  BOOKS_AND_REFERENCE
# 2382                                     Cloud of Books  BOOKS_AND_REFERENCE
# 541                                   Al Quran Al karim  BOOKS_AND_REFERENCE
# 584                        All Language Translator Free  BOOKS_AND_REFERENCE
# 585                                  All Maths Formulas  BOOKS_AND_REFERENCE
# 1624  Brilliant Quotes: Life, Love, Family & Motivation  BOOKS_AND_REFERENCE
# 1579                                         Book store  BOOKS_AND_REFERENCE
# 3334                                       EGW Writings  BOOKS_AND_REFERENCE
# 550                         Al-Quran 30 Juz free copies  BOOKS_AND_REFERENCE
# 539                         Al Quran (Tafsir & by Word)  BOOKS_AND_REFERENCE
# 3679                         English Persian Dictionary  BOOKS_AND_REFERENCE
# 3676                  English Grammar Complete Handbook  BOOKS_AND_REFERENCE
# 831                                       Azpen eReader  BOOKS_AND_REFERENCE
# 1450                            Bible with EGW Comments  BOOKS_AND_REFERENCE
# 415                              Aab e Hayat Full Novel  BOOKS_AND_REFERENCE
# 3116                 Download free book with green book  BOOKS_AND_REFERENCE
# 1289                                      BakaReader EX  BOOKS_AND_REFERENCE
# 3335                                     EGW Writings 2  BOOKS_AND_REFERENCE
# 2855                         DV 2019 - EDV Photo & Form  BOOKS_AND_REFERENCE
# 1706                           C Programs and Reference  BOOKS_AND_REFERENCE
# 1449                       Bible du Semeur-BDS (French)  BOOKS_AND_REFERENCE
# 548                                         Al-Muhaffiz  BOOKS_AND_REFERENCE
# 3245                   E-Book Read - Read Book for free  BOOKS_AND_REFERENCE
# 3531                                           EZ Quran  BOOKS_AND_REFERENCE
# 1705                                C Programs Handbook  BOOKS_AND_REFERENCE
# 2731                                          DM Screen  BOOKS_AND_REFERENCE
# 2856                                DV 2019 Entry Guide  BOOKS_AND_REFERENCE
# 485                              Ae Allah na Dai (Rasa)  BOOKS_AND_REFERENCE
# 492                                 Ag PhD Deficiencies  BOOKS_AND_REFERENCE
# 1662                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 3558                                 Easy Cv maker 2018  BOOKS_AND_REFERENCE
# 302                          AP Stamps and Registration  BOOKS_AND_REFERENCE
# 3680                        English To Shona Dictionary  BOOKS_AND_REFERENCE
# 1589                             Borneo Bible, BM Bible  BOOKS_AND_REFERENCE
# 896                                    BD All Sim Offer  BOOKS_AND_REFERENCE
# 679                          Anonymous caller detection  BOOKS_AND_REFERENCE
# 1123                     BR Ambedkar Biography & Quotes  BOOKS_AND_REFERENCE
# 1587                       Bootable Methods(USB-CD-DVD)  BOOKS_AND_REFERENCE
# 840                                         B&H Kids AR  BOOKS_AND_REFERENCE
# 816                        Ay Hasnain k Nana Milad Naat  BOOKS_AND_REFERENCE
# 817                       Ay Mohabbat Teri Khatir Novel  BOOKS_AND_REFERENCE
# 493                                  Ag PhD Field Guide  BOOKS_AND_REFERENCE
# 2625                                           DC HSEMA  BOOKS_AND_REFERENCE
# 1632                         Browsery by Barnes & Noble  BOOKS_AND_REFERENCE
# 402                                             AY Sing  BOOKS_AND_REFERENCE
# 3272                                EC - AP & Telangana  BOOKS_AND_REFERENCE
# 839                                      B y H Niños ES  BOOKS_AND_REFERENCE
# 387                        AW Tozer Devotionals - Daily  BOOKS_AND_REFERENCE
# 3217                                    Duaa Ek Ibaadat  BOOKS_AND_REFERENCE
# 1467                     Bilingual Dictionary Audio App  BOOKS_AND_REFERENCE
# 140    AC Air condition Troubleshoot,Repair,Maintenance  BOOKS_AND_REFERENCE
# 1724           CA Laws 2018 (California Laws and Codes)  BOOKS_AND_REFERENCE
# 3447                                         EU Charter  BOOKS_AND_REFERENCE
# 3402                                EP Research Service  BOOKS_AND_REFERENCE
# 496                             Ag PhD Soybean Diseases  BOOKS_AND_REFERENCE
# 177                                        AE Bulletins  BOOKS_AND_REFERENCE
# 730                      Arizona Statutes, ARS (AZ Law)  BOOKS_AND_REFERENCE
# 3257                                 EB Annual Meetings  BOOKS_AND_REFERENCE
# 3449                                 EU Data Protection  BOOKS_AND_REFERENCE
# 1700                                 C Offline Tutorial  BOOKS_AND_REFERENCE
# 3141                                    Dr. Doug's Tips  BOOKS_AND_REFERENCE
# 2630                                  DC Public Library  BOOKS_AND_REFERENCE
# 2296                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 905                                        BD Fishpedia  BOOKS_AND_REFERENCE
# 2595                          D. H. Lawrence Poems FREE  BOOKS_AND_REFERENCE
# 2066                                         CW Nuclear  BOOKS_AND_REFERENCE
# 2854                              DV 2018 Winners Guide  BOOKS_AND_REFERENCE
# 494               Ag PhD Planting Population Calculator  BOOKS_AND_REFERENCE
# 1055                                             BM Box  BOOKS_AND_REFERENCE
# 2243                              Catholic La Bu Zo Kam  BOOKS_AND_REFERENCE
# 3458                                        EU IP Codes  BOOKS_AND_REFERENCE
# 1176                                          BU Alsace  BOOKS_AND_REFERENCE
# 673                                    Anime Mod for BM  BOOKS_AND_REFERENCE
# 2443                       CompactiMa EC pH Calibration  BOOKS_AND_REFERENCE
# 2585                            Cypress College Library  BOOKS_AND_REFERENCE
# 108                                     A-J Media Vault  BOOKS_AND_REFERENCE
# 2095                                    CY Spray nozzle  BOOKS_AND_REFERENCE
# 3485                                             EW PDF  BOOKS_AND_REFERENCE
# 1451                             BibleRead En Cy Zh Yue  BOOKS_AND_REFERENCE
# 2102                                            CZ-Help  BOOKS_AND_REFERENCE
#
#      Rating  Reviews                Size   Installs  Type Price  \
# 615     4.2   814151  Varies with device  100000000  Free     0
# 1446    4.7  2440695  Varies with device  100000000  Free     0
# 770     4.5   568922  Varies with device  100000000  Free     0
# 2480    4.5   246315  Varies with device   10000000  Free     0
# 3678    4.4   384368  Varies with device   10000000  Free     0
# 3675    4.4   341234                 30M   10000000  Free     0
# 546     4.6   361780                9.7M   10000000  Free     0
# 3015    4.6   899010  Varies with device   10000000  Free     0
# 543     4.8   445756                 16M   10000000  Free     0
# 3013    4.5   454412  Varies with device   10000000  Free     0
# 3012    4.5   264260  Varies with device   10000000  Free     0
# 549     4.6   218451                4.7M   10000000  Free     0
# 566     4.2   210534                 22M   10000000  Free     0
# 81      4.1    52312                 11M    5000000  Free     0
# 637     4.3    64513  Varies with device    5000000  Free     0
# 1447    4.5    42729  Varies with device    5000000  Free     0
# 3014    4.6   124970  Varies with device    5000000  Free     0
# 3586    4.1    85842                 37M    5000000  Free     0
# 553     4.6    90468                5.9M    5000000  Free     0
# 3685    4.1    71328                 11M    5000000  Free     0
# 540     4.5    96419  Varies with device    5000000  Free     0
# 2382    3.3     1862                 19M    1000000  Free     0
# 541     4.6    41608                 49M    1000000  Free     0
# 584     4.4    30105                2.1M    1000000  Free     0
# 585     4.4     2709                6.8M    1000000  Free     0
# 1624    4.5    67186                6.3M    1000000  Free     0
# 1579    4.4    22486                5.4M    1000000  Free     0
# 3334    4.7    24278                3.1M    1000000  Free     0
# 550     4.5    12322                 27M     500000  Free     0
# 539     4.8    57400                 14M     500000  Free     0
# 3679    4.5    26875                 73M     500000  Free     0
# 3676    4.6     1435                2.8M     500000  Free     0
# 831     3.5      156                 42M     500000  Free     0
# 1450    4.7     3776                 12M     100000  Free     0
# 415     4.3     1476                 41M     100000  Free     0
# 3116    4.6     4478                9.5M     100000  Free     0
# 1289    4.3     8894                2.3M     100000  Free     0
# 3335    4.7     6547                 16M     100000  Free     0
# 2855    3.9      314                2.6M      50000  Free     0
# 1706    4.2      873                2.5M      50000  Free     0
# 1449    4.5      313                6.9M      50000  Free     0
# 548     4.7     2319                 27M      50000  Free     0
# 3245    4.5     1857                4.9M      50000  Free     0
# 3531    4.6      595                8.5M      50000  Free     0
# 1705    4.0      459                3.1M      50000  Free     0
# 2731    4.4      283                5.4M      10000  Free     0
# 2856    4.5       92                5.1M      10000  Free     0
# 485     4.7      263                9.1M      10000  Free     0
# 492     3.9       20                9.7M      10000  Free     0
# 1662    4.6      603                7.4M      10000  Free     0
# 3558    3.9       88                5.3M      10000  Free     0
# 302     3.4       82                2.7M      10000  Free     0
# 3680    4.6       60                3.7M      10000  Free     0
# 1589    4.9      659                5.0M      10000  Free     0
# 896     4.5      197                2.8M      10000  Free     0
# 679     NaN      161                2.7M      10000  Free     0
# 1123    4.6      156                2.1M      10000  Free     0
# 1587    3.4       37                3.4M      10000  Free     0
# 840     3.9      286                 18M      10000  Free     0
# 816     4.3       72                1.9M      10000  Free     0
# 817     4.2       27                4.3M      10000  Free     0
# 493     4.1      114                6.3M      10000  Free     0
# 2625    3.8       38                7.2M       5000  Free     0
# 1632    4.7      146                 34M       5000  Free     0
# 402     4.8      111                 10M       5000  Free     0
# 3272    3.5       10                3.0M       5000  Free     0
# 839     4.6       53                 16M       5000  Free     0
# 387     4.2        8                3.9M       5000  Free     0
# 3217    4.9      122                 26M       5000  Free     0
# 1467    2.7       68                 87M       5000  Free     0
# 140     4.2       27                3.1M       5000  Free     0
# 1724    3.9       56                 38M       5000  Free     0
# 3447    4.6       33                 37M       1000  Free     0
# 3402    4.7       14                 27M       1000  Free     0
# 496     NaN        0                5.9M       1000  Free     0
# 177     4.5       14                 30M       1000  Free     0
# 730     3.9        9                8.8M       1000  Free     0
# 3257    3.5       11                 15M       1000  Free     0
# 3449    3.5       29                 17M       1000  Free     0
# 1700    4.7       88                4.2M       1000  Free     0
# 3141    4.0       22                 34M       1000  Free     0
# 2630    4.2       20                3.4M       1000  Free     0
# 2296    4.8       44                619k       1000  Free     0
# 905     4.8      123                6.5M       1000  Free     0
# 2595    NaN       13                942k       1000  Free     0
# 2066    3.3       15                 12M       1000  Free     0
# 2854    4.8       11                608k       1000  Free     0
# 494     NaN        0                5.2M       1000  Free     0
# 1055    4.3       28  Varies with device       1000  Free     0
# 2243    5.0       23  Varies with device        500  Free     0
# 3458    NaN        2                970k        100  Free     0
# 1176    NaN        3                4.0M        100  Free     0
# 673     NaN        0                8.0M        100  Free     0
# 2443    NaN        0                8.4M        100  Free     0
# 2585    NaN        0                2.1M        100  Free     0
# 108     NaN        1                 24M         50  Free     0
# 2095    NaN        0                3.3M         10  Free     0
# 3485    NaN        0                8.7M          5  Free     0
# 1451    NaN        0                 12M          5  Free     0
# 2102    5.0        2                1.4M          5  Free     0
#
#      Content Rating             Genres        Last Updated  \
# 615            Teen  Books & Reference       July 27, 2018
# 1446           Teen  Books & Reference      August 2, 2018
# 770            Teen  Books & Reference      August 1, 2018
# 2480       Everyone  Books & Reference       July 17, 2015
# 3678       Everyone  Books & Reference      August 4, 2018
# 3675   Everyone 10+  Books & Reference      March 20, 2018
# 546        Everyone  Books & Reference        May 30, 2018
# 3015       Everyone  Books & Reference       July 30, 2018
# 543        Everyone  Books & Reference        May 15, 2018
# 3013       Everyone  Books & Reference        May 18, 2018
# 3012       Everyone  Books & Reference       June 22, 2018
# 549        Everyone  Books & Reference        May 20, 2018
# 566        Everyone  Books & Reference       June 13, 2018
# 81             Teen  Books & Reference        May 19, 2018
# 637        Everyone  Books & Reference       July 31, 2018
# 1447       Everyone  Books & Reference   November 26, 2014
# 3014           Teen  Books & Reference        May 26, 2018
# 3586       Everyone  Books & Reference       June 25, 2018
# 553        Everyone  Books & Reference        May 27, 2018
# 3685       Everyone  Books & Reference       June 11, 2017
# 540        Everyone  Books & Reference         May 5, 2018
# 2382       Everyone  Books & Reference      April 27, 2018
# 541        Everyone  Books & Reference    November 5, 2017
# 584        Everyone  Books & Reference       July 29, 2018
# 585        Everyone  Books & Reference       July 11, 2018
# 1624   Everyone 10+  Books & Reference        May 18, 2018
# 1579           Teen  Books & Reference        June 6, 2018
# 3334       Everyone  Books & Reference   December 27, 2017
# 550        Everyone  Books & Reference   December 17, 2016
# 539        Everyone  Books & Reference       July 30, 2018
# 3679       Everyone  Books & Reference      August 1, 2018
# 3676       Everyone  Books & Reference    January 21, 2018
# 831        Everyone  Books & Reference   February 15, 2018
# 1450       Everyone  Books & Reference    February 7, 2018
# 415        Everyone  Books & Reference   February 21, 2017
# 3116   Everyone 10+  Books & Reference       July 31, 2017
# 1289       Everyone  Books & Reference       July 23, 2018
# 3335       Everyone  Books & Reference    December 8, 2017
# 2855       Everyone  Books & Reference    October 24, 2016
# 1706       Everyone  Books & Reference       July 31, 2014
# 1449       Everyone  Books & Reference      August 4, 2018
# 548        Everyone  Books & Reference      April 22, 2018
# 3245       Everyone  Books & Reference      August 3, 2018
# 3531       Everyone  Books & Reference       June 28, 2016
# 1705       Everyone  Books & Reference   November 16, 2017
# 2731   Everyone 10+  Books & Reference    January 12, 2018
# 2856       Everyone  Books & Reference    October 18, 2017
# 485        Everyone  Books & Reference     January 1, 2015
# 492        Everyone  Books & Reference       June 21, 2016
# 1662       Everyone  Books & Reference       June 19, 2016
# 3558       Everyone  Books & Reference      March 31, 2018
# 302        Everyone  Books & Reference      March 27, 2018
# 3680       Everyone  Books & Reference       July 10, 2016
# 1589       Everyone  Books & Reference     August 28, 2017
# 896        Everyone  Books & Reference     January 3, 2017
# 679        Everyone  Books & Reference       July 13, 2018
# 1123       Everyone  Books & Reference       June 11, 2018
# 1587       Everyone  Books & Reference        May 31, 2018
# 840        Everyone  Books & Reference  September 29, 2017
# 816        Everyone  Books & Reference   December 21, 2015
# 817        Everyone  Books & Reference    January 30, 2018
# 493        Everyone  Books & Reference        May 25, 2015
# 2625       Everyone  Books & Reference       June 18, 2018
# 1632       Everyone  Books & Reference      April 30, 2018
# 402        Everyone  Books & Reference        May 21, 2018
# 3272       Everyone  Books & Reference   November 10, 2017
# 839        Everyone  Books & Reference  September 22, 2015
# 387        Everyone  Books & Reference     October 7, 2016
# 3217       Everyone  Books & Reference      April 10, 2016
# 1467       Everyone  Books & Reference         May 2, 2018
# 140        Everyone  Books & Reference    February 7, 2018
# 1724       Everyone  Books & Reference      March 24, 2018
# 3447       Everyone  Books & Reference    January 16, 2017
# 3402       Everyone  Books & Reference       March 5, 2018
# 496        Everyone  Books & Reference         May 8, 2017
# 177        Everyone  Books & Reference       July 18, 2018
# 730        Everyone  Books & Reference    October 18, 2017
# 3257       Everyone  Books & Reference      April 13, 2018
# 3449       Everyone  Books & Reference       July 15, 2016
# 1700       Everyone  Books & Reference    December 8, 2017
# 3141       Everyone  Books & Reference   September 1, 2016
# 2630       Everyone  Books & Reference        June 8, 2015
# 2296       Everyone  Books & Reference      March 23, 2014
# 905        Everyone  Books & Reference      March 15, 2017
# 2595       Everyone  Books & Reference   November 22, 2013
# 2066       Everyone  Books & Reference   November 17, 2017
# 2854       Everyone  Books & Reference       July 23, 2017
# 494        Everyone  Books & Reference        June 9, 2017
# 1055       Everyone  Books & Reference    October 20, 2016
# 2243       Everyone  Books & Reference      March 20, 2016
# 3458       Everyone  Books & Reference     January 8, 2014
# 1176       Everyone  Books & Reference     October 3, 2017
# 673        Everyone  Books & Reference       July 28, 2017
# 2443       Everyone  Books & Reference   December 22, 2016
# 2585       Everyone  Books & Reference    December 7, 2015
# 108        Everyone  Books & Reference     January 4, 2017
# 2095       Everyone  Books & Reference      August 3, 2017
# 3485       Everyone  Books & Reference   February 14, 2018
# 1451       Everyone  Books & Reference        May 17, 2018
# 2102       Everyone  Books & Reference       July 13, 2018
#
#              Current Ver         Android Ver
# 615   Varies with device  Varies with device
# 1446  Varies with device  Varies with device
# 770   Varies with device  Varies with device
# 2480  Varies with device          1.5 and up
# 3678  Varies with device  Varies with device
# 3675               3.9.1          4.2 and up
# 546                  4.1          2.3 and up
# 3015  Varies with device  Varies with device
# 543               2.6.22          4.0 and up
# 3013  Varies with device  Varies with device
# 3012  Varies with device  Varies with device
# 549                3.2.3          4.0 and up
# 566               3.0.58          4.0 and up
# 81                 5.3.4          4.4 and up
# 637   Varies with device  Varies with device
# 1447  Varies with device  Varies with device
# 3014  Varies with device  Varies with device
# 3586               5.0.6          4.0 and up
# 553          1.911805270          2.3 and up
# 3685          BlueOrange        4.0.3 and up
# 540   Varies with device  Varies with device
# 2382               2.2.5          4.1 and up
# 541                1.1.7          2.2 and up
# 584                 1.15        4.0.3 and up
# 585                  1.9          4.4 and up
# 1624              4.4.10        2.3.3 and up
# 1579               3.2.1          4.0 and up
# 3334               2.1.2          2.2 and up
# 550                  3.0          2.3 and up
# 539                1.6.5          4.0 and up
# 3679               6.0.8        4.0.3 and up
# 3676                 1.0          4.0 and up
# 831              3.1.7.9          2.2 and up
# 1450              2.12.0          4.1 and up
# 415                  1.0          3.0 and up
# 3116                 1.1          4.0 and up
# 1289              1.1.51          4.0 and up
# 3335               4.0.3        4.0.3 and up
# 2855               6.0.0        4.0.3 and up
# 1706                 2.2          2.1 and up
# 1449                 0.7          1.0 and up
# 548                10.10          4.1 and up
# 3245               1.3.2          4.4 and up
# 3531                 6.0          4.1 and up
# 1705             2.2.3.3          4.0 and up
# 2731             1.1.10a          4.0 and up
# 2856               2.0.0          4.1 and up
# 485                  2.0          2.1 and up
# 492                  1.0        4.0.3 and up
# 1662                2.96          4.1 and up
# 3558                 1.1          4.0 and up
# 302                  2.0          3.0 and up
# 3680                 1.4          3.0 and up
# 1589               4.4.5          4.0 and up
# 896                  1.2          4.1 and up
# 679                  1.0          2.3 and up
# 1123                 2.0          2.3 and up
# 1587                 1.5          4.0 and up
# 840                3.2.5          4.0 and up
# 816                  1.0          2.3 and up
# 817                  1.0          4.0 and up
# 493                  2.0          2.3 and up
# 2625                 4.0          4.4 and up
# 1632               1.1.3          4.4 and up
# 402                1.6.2          4.1 and up
# 3272                 1.0        4.0.3 and up
# 839                1.0.2          2.3 and up
# 387                  1.0          2.3 and up
# 3217                 1.5          2.2 and up
# 1467            1.0.0.22          4.1 and up
# 140                  1.1          4.0 and up
# 1724                1.17          4.4 and up
# 3447               1.0.3          4.0 and up
# 3402                 1.9          4.1 and up
# 496                1.0.3        4.0.3 and up
# 177                2.2.5        4.0.3 and up
# 730                  1.6          4.4 and up
# 3257             9.4.7.6          4.0 and up
# 3449                 2.0        4.0.3 and up
# 1700               1.0.1          4.1 and up
# 3141                 1.1          2.3 and up
# 2630               4.6.1          1.6 and up
# 2296                 0.8          2.2 and up
# 905              3.15317          3.0 and up
# 2595                1.11        2.3.3 and up
# 2066                 1.2          4.0 and up
# 2854                1.09          4.2 and up
# 494                  2.0        4.0.3 and up
# 1055  Varies with device  Varies with device
# 2243               0.0.1          4.0 and up
# 3458               1.0.4          4.0 and up
# 1176               3.1.1          2.3 and up
# 673                  1.0          4.0 and up
# 2443               1.1.2          4.1 and up
# 2585               4.7.2          1.6 and up
# 108               5.62.1        4.0.3 and up
# 2095             1.01.00        4.0.3 and up
# 3485               1.0.2          4.4 and up
# 1451                 1.0          4.0 and up
# 2102                 0.1          4.4 and up

# %%
pandas_appstore[pandas_appstore["prime_genre"] == "Reference"][:100].sort_values("rating_count_tot", ascending = False)
# Out:
#               id                                         track_name  \
# 256    282935706                                              Bible
# 659    308750436              Dictionary.com Dictionary & Thesaurus
# 660    364740856     Dictionary.com Dictionary & Thesaurus for iPad
# 1148   414706506                                   Google Translate
# 1742   388389451  Muslim Pro: Ramadan 2017 Prayer Times, Azan, Q...
# 1830  1130829481  New Furniture Mods - Pocket Wiki & Game Tools ...
# 1651   399452287                         Merriam-Webster Dictionary
# 1840   475772902                                          Night Sky
# 484   1135575003  City Maps for Minecraft PE - The Best Maps for...
# 1478  1132715891  LUCKY BLOCK MOD ™ for Minecraft PC Edition - T...
# 1062  1137683736    GUNS MODS for Minecraft PC Edition - Mods Tools
# 1168  1133678984  Guides for Pokémon GO - Pokemon GO News and Ch...
# 2945   640199958                                               WWDC
# 1264  1133706938  Horror Maps for Minecraft PE - Download The Sc...
# 2872  1003837100                                        VPN Express
# 2160  1156856246    Real Bike Traffic Rider Virtual Reality Glasses
# 1379   671889349  Jishokun-Japanese English Dictionary & Translator
# 3205   980134624                                            教えて!goo
#
#      size_bytes currency price  rating_count_tot rating_count_ver user_rating  \
# 256    92774400      USD   0.0            985920             5320         4.5
# 659   111275008      USD   0.0            200047              177         4.0
# 660   165748736      USD   0.0             54175            10176         4.5
# 1148   65281024      USD   0.0             26786               27         3.5
# 1742  100551680      USD   0.0             18418              706         4.5
# 1830   52959232      USD   0.0             17588            17588         4.5
# 1651  155593728      USD   0.0             16849             1125         4.5
# 1840  596499456      USD   0.0             12122               60         4.5
# 484    90124288      USD   0.0              8535             8535         4.0
# 1478   86874112      USD   0.0              4693             4693         4.0
# 1062   85424128      USD   0.0              1497              245         4.0
# 1168   27029504      USD   0.0               826               58         4.5
# 2945   34959360      USD   0.0               762                7         3.5
# 1264   89927680      USD   0.0               718              718         4.0
# 2872   10645504      USD   0.0                14                1         4.5
# 2160  125990912      USD   0.0                 8                2         3.0
# 1379  225522688      USD   0.0                 0                0         0.0
# 3205   44208128      USD   0.0                 0                0         0.0
#
#      user_rating_ver      ver cont_rating prime_genre sup_devices.num  \
# 256              5.0    7.5.1          4+   Reference              37
# 659              4.0    7.1.3          4+   Reference              37
# 660              4.5      4.0          4+   Reference              24
# 1148             4.5   5.10.0          4+   Reference              37
# 1742             5.0    9.2.1          4+   Reference              37
# 1830             4.5      1.0          4+   Reference              38
# 1651             4.5      4.1          4+   Reference              38
# 1840             4.5    4.4.1          4+   Reference              37
# 484              4.0      1.0          4+   Reference              37
# 1478             4.0      1.0         12+   Reference              37
# 1062             3.0      1.1         12+   Reference              37
# 1168             4.0      1.1         17+   Reference              37
# 2945             4.5    6.0.0          4+   Reference              37
# 1264             4.0      1.0         12+   Reference              37
# 2872             5.0      1.8          4+   Reference              37
# 2160             4.5      8.9         17+   Reference              40
# 1379             0.0  2.10.14         12+   Reference              37
# 3205             0.0    2.2.3         12+   Reference              37
#
#      ipadSc_urls.num lang.num vpp_lic
# 256                5       45       1
# 659                0        1       1
# 660                5        9       1
# 1148               5       59       1
# 1742               5       16       1
# 1830               3        2       1
# 1651               1       12       1
# 1840               5       29       1
# 484                4        1       1
# 1478               4        1       1
# 1062               4        1       1
# 1168               2        1       1
# 2945               5        1       1
# 1264               4        1       1
# 2872               2        2       1
# 2160               5        1       1
# 1379               4        2       1
# 3205               0        1       1

# %% [markdown]
# > It seems like the applications associated with religion and languages are very popular in both markets, suggesting that building an app around such kinds of books is profitable in both stores. The popular applications center around the "Quran" and the "Bible" and so creating an application for other religions could prove to be a profitable idea. Adding features such as translations and audio recordings could also help attract more user downloads, leading to higher profitability.

# %% [markdown]
# ## Conclusion
# > The goal of this project was to find a profitable mobile app idea for both the Apple App Store and the Google Play Store. After analyzing both markets, we have narrowed down our findings to building a "Reference" application centered around a religious book. However, adding extra features to the application such as a translation and an audio recording option could help add to its uniqueness and generate more installs, leading to higher profits.

# %%
# %%html
# <style>
# .nbviewer div.output_area {
#   overflow-y: auto;
#   max-height: 400px;
# }
# </style>
# Out:
# <style>
# .nbviewer div.output_area {
#   overflow-y: auto;
#   max-height: 400px;
# }
# </style>
